# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load data for training the model

# %%
df = pd.read_csv('training_data.csv')

df.head()
# Out:
#    itching  skin_rash  ...  yellow_crust_ooze         prognosis
# 0        1          1  ...                  0  Fungal infection
# 1        0          1  ...                  0  Fungal infection
# 2        1          0  ...                  0  Fungal infection
# 3        1          1  ...                  0  Fungal infection
# 4        1          1  ...                  0  Fungal infection
#
# [5 rows x 132 columns]

# %%
X = df.iloc[:, :-1]
y = df['prognosis']

# %% [markdown]
# Split the data for training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %% [markdown]
# Train the model using random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(n_estimators=200,min_samples_leaf=3,max_features=100, max_depth=10)

# %%
rf_clf.fit(X_train, y_train)

accuracy = rf_clf.score(X_test,y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.964769647696477

# %% [markdown]
# Create a dictionary with symptoms as keys and indices as values

# %%
symptoms_dict = {}

for index, symptom in enumerate(X):
    symptoms_dict[symptom] = index

# %%
symptoms_dict
# Out:
# {'abdominal_pain': 39,
#  'abnormal_menstruation': 100,
#  'acidity': 8,
#  'acute_liver_failure': 44,
#  'altered_sensorium': 97,
#  'anxiety': 16,
#  'back_pain': 37,
#  'belly_pain': 99,
#  'blackheads': 122,
#  'bladder_discomfort': 88,
#  'blister': 128,
#  'blood_in_sputum': 117,
#  'bloody_stool': 60,
#  'blurred_and_distorted_vision': 48,
#  'breathlessness': 27,
#  'brittle_nails': 71,
#  'bruising': 65,
#  'burning_micturition': 12,
#  'chest_pain': 55,
#  'chills': 5,
#  'cold_hands_and_feets': 17,
#  'coma': 112,
#  'congestion': 54,
#  'constipation': 38,
#  'continuous_feel_of_urine': 90,
#  'continuous_sneezing': 3,
#  'cough': 24,
#  'cramps': 64,
#  'dark_urine': 33,
#  'dehydration': 29,
#  'depression': 94,
#  'diarrhoea': 40,
#  'dischromic _patches': 101,
#  'distention_of_abdomen': 114,
#  'dizziness': 63,
#  'drying_and_tingling_lips': 75,
#  'enlarged_thyroid': 70,
#  'excessive_hunger': 73,
#  'extra_marital_contacts': 74,
#  'family_history': 105,
#  'fast_heart_rate': 57,
#  'fatigue': 14,
#  'fluid_overload': 116,
#  'foul_smell_of urine': 89,
#  'headache': 31,
#  'high_fever': 25,
#  'hip_joint_pain': 78,
#  'history_of_alcohol_consumption': 115,
#  'increased_appetite': 103,
#  'indigestion': 30,
#  'inflammatory_nails': 127,
#  'internal_itching': 92,
#  'irregular_sugar_level': 23,
#  'irritability': 95,
#  'irritation_in_anus': 61,
#  'itching': 0,
#  'joint_pain': 6,
#  'knee_pain': 77,
#  'lack_of_concentration': 108,
#  'lethargy': 21,
#  'loss_of_appetite': 35,
#  'loss_of_balance': 84,
#  'loss_of_smell': 87,
#  'malaise': 47,
#  'mild_fever': 41,
#  'mood_swings': 18,
#  'movement_stiffness': 82,
#  'mucoid_sputum': 106,
#  'muscle_pain': 96,
#  'muscle_wasting': 10,
#  'muscle_weakness': 79,
#  'nausea': 34,
#  'neck_pain': 62,
#  'nodal_skin_eruptions': 2,
#  'obesity': 66,
#  'pain_behind_the_eyes': 36,
#  'pain_during_bowel_movements': 58,
#  'pain_in_anal_region': 59,
#  'painful_walking': 120,
#  'palpitations': 119,
#  'passage_of_gases': 91,
#  'patches_in_throat': 22,
#  'phlegm': 49,
#  'polyuria': 104,
#  'prominent_veins_on_calf': 118,
#  'puffy_face_and_eyes': 69,
#  'pus_filled_pimples': 121,
#  'receiving_blood_transfusion': 110,
#  'receiving_unsterile_injections': 111,
#  'red_sore_around_nose': 129,
#  'red_spots_over_body': 98,
#  'redness_of_eyes': 51,
#  'restlessness': 20,
#  'runny_nose': 53,
#  'rusty_sputum': 107,
#  'scurring': 123,
#  'shivering': 4,
#  'silver_like_dusting': 125,
#  'sinus_pressure': 52,
#  'skin_peeling': 124,
#  'skin_rash': 1,
#  'slurred_speech': 76,
#  'small_dents_in_nails': 126,
#  'spinning_movements': 83,
#  'spotting_ urination': 13,
#  'stiff_neck': 80,
#  'stomach_bleeding': 113,
#  'stomach_pain': 7,
#  'sunken_eyes': 26,
#  'sweating': 28,
#  'swelled_lymph_nodes': 46,
#  'swelling_joints': 81,
#  'swelling_of_stomach': 45,
#  'swollen_blood_vessels': 68,
#  'swollen_extremeties': 72,
#  'swollen_legs': 67,
#  'throat_irritation': 50,
#  'toxic_look_(typhos)': 93,
#  'ulcers_on_tongue': 9,
#  'unsteadiness': 85,
#  'visual_disturbances': 109,
#  'vomiting': 11,
#  'watering_from_eyes': 102,
#  'weakness_in_limbs': 56,
#  'weakness_of_one_body_side': 86,
#  'weight_gain': 15,
#  'weight_loss': 19,
#  'yellow_crust_ooze': 130,
#  'yellow_urine': 42,
#  'yellowing_of_eyes': 43,
#  'yellowish_skin': 32}

# %% [markdown]
# Predict for sample data

# %%
input_vector = np.zeros(len(symptoms_dict))

# %%
input_vector[[symptoms_dict['cramps'], symptoms_dict['cough']]] = 1

# %%
rf_clf.predict_proba([input_vector])
# Out:
# array([[0.02621719, 0.03045568, 0.02366465, 0.02773041, 0.0297265 ,
#         0.01885503, 0.02132245, 0.0294222 , 0.01997755, 0.02911403,
#         0.01408513, 0.0170019 , 0.02244866, 0.01742526, 0.02279074,
#         0.02572377, 0.02418948, 0.02992562, 0.03485639, 0.02329037,
#         0.03128534, 0.0325019 , 0.01624795, 0.01181711, 0.01944697,
#         0.00908729, 0.01853044, 0.02167175, 0.03098886, 0.02297637,
#         0.0191659 , 0.02096834, 0.02544874, 0.02419107, 0.02255214,
#         0.02544729, 0.01584888, 0.02676987, 0.02177085, 0.08255387,
#         0.01250605]])

# %%
rf_clf.predict([input_vector])
# Out:
# array(['Varicose veins'], dtype=object)

# %%
import pickle

# %%
filename = 'finalized_model.sav'
pickle.dump(rf_clf, open(filename, 'wb'))
